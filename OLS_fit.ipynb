# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
X = np.array([[1], [1], [2], [2]])
y = 1 * X + 2 * X + 3
# y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression(fit_intercept=0).fit(X, y)
reg.score(X, y)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))


##############################333333
# Fit the linear regression model
# X = sm.add_constant(X) # Add a constant term to the X variables
model = sm.OLS(y, X).fit()

# Print the model summary to see the p-values
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              192.0
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):                    0.000814
# Time:                        16:53:02   Log-Likelihood:                         -5.4650
# No. Observations:                   4   AIC:                                      12.93
# Df Residuals:                       3   BIC:                                      12.32
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
results=model.summary().as_csv()

print(model.params)
print(model.pvalues)
df = pd.read_html(model.summary().tables[1].as_html(),header=0,index_col=0)[0]
df
# Out:
# [4.8]
# [0.00081365]
# /usr/local/lib/python3.8/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.8/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#     coef  std err       t  P>|t|  [0.025  0.975]
# x1   4.8    0.346  13.856  0.001   3.698   5.902

# %%
pd.read_html(model.summary().tables[0].as_html(),header=0,index_col=0)[0]
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                   y       R-squared (uncentered):       0.985
# Dep. Variable:
# Model:                          OLS  Adj. R-squared (uncentered):    0.979000
# Method:               Least Squares                  F-statistic:  192.000000
# Date:              Mon, 06 Mar 2023           Prob (F-statistic):    0.000814
# Time:                      16:53:02               Log-Likelihood:   -5.465000
# No. Observations:                 4                          AIC:   12.930000
# Df Residuals:                     3                          BIC:   12.320000
# Df Model:                         1                           NaN         NaN
# Covariance Type:          nonrobust                           NaN         NaN

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
data = pd.read_csv("data.csv")

# Create the X and y variables
X = data[['x1', 'x2', 'x3']]
y = data['y']

# Fit the linear regression model
X = sm.add_constant(X) # Add a constant term to the X variables
model = sm.OLS(y, X).fit()

# Print the model summary to see the p-values
print(model.summary())
